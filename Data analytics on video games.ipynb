# %%
import pandas as pd
import os
dataset_path = r'C:\Users\jerom\Desktop'
file_path = os.path.join(dataset_path,'vgsales.csv')
df = pd.read_csv(file_path)
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
df.values
# Out:
# array([[1, 'Wii Sports', 'Wii', ..., 3.77, 8.46, 82.74],
#        [2, 'Super Mario Bros.', 'NES', ..., 6.81, 0.77, 40.24],
#        [3, 'Mario Kart Wii', 'Wii', ..., 3.79, 3.31, 35.82],
#        ...,
#        [16598, 'SCORE International Baja 1000: The Official Game', 'PS2',
#         ..., 0.0, 0.0, 0.01],
#        [16599, 'Know How 2', 'DS', ..., 0.0, 0.0, 0.01],
#        [16600, 'Spirits & Spells', 'GBA', ..., 0.0, 0.0, 0.01]],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
# Bar chart
genre_sales = df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
plt.figure(figsize=(10, 6))
genre_sales.plot(kind='bar', color='skyblue')
plt.title('Total Global Sales by Genre')
plt.xlabel('Genre')
plt.ylabel('Global Sales (in millions)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(df['Year'], df['Global_Sales'], color='orange', alpha=0.5)
plt.title('Year vs Global Sales')
plt.xlabel('Year')
plt.ylabel('Global Sales (in millions)')
plt.grid(True)
plt.show()

# %%
# missing valeus
missing_values = df.isnull().sum()
df.dropna(inplace=True)
df.fillna(df.mean(), inplace=True)
# Out:
# C:\Users\jerom\AppData\Local\Temp\ipykernel_1224\872936642.py:8: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
# Identify duplicate rows
duplicate_rows = df.duplicated()
df.drop_duplicates(inplace=True)

# %%
#box plot
plt.figure(figsize=(10, 6))
plt.boxplot(df['NA_Sales'])
plt.title('Box Plot of Numeric Column')
plt.ylabel('Values')
plt.show()
